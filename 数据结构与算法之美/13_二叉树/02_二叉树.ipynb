# %% [markdown]
# # 二叉树
# - 每个节点最多有两个子节点的树
# - 满二叉树：每个节点都有0或2个子节点
# - 完全二叉树：除了最后一层，其他层都是满的，且最后一层的节点都靠左排列

# %% [markdown]
# ## 存储二叉树
# - 顺序存储：将二叉树的节点按照层次顺序存储在数组中，节点i的左子节点为2i，右子节点为2i+1
# - 链式存储：每个节点有两个指针，分别指向左右子节点

# %% [markdown]
# ## 二叉树遍历
# - 前序遍历：根-左-右
# - 中序遍历：左-根-右
# - 后序遍历：左-右-根
# 前、中、后序遍历中每个节点最多会被访问两次，所以遍历操作的时间复杂度，跟节点的个数 n 成正比，也就是说二叉树遍历的时间复杂度是 O(n)
